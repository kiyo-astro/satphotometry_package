# %% [markdown]
# # Identify Objects in Observed Image
# Written by Kiyoaki Okudaira<br>
# *Kyushu University Hanada Lab / University of Washington / IAU CPS SatHub<br>
# (okudaira.kiyoaki.528@s.kyushu-u.ac.jp or kiyoaki@uw.edu)<br>
# <br>
# Identify satellites and debris in observed FITS image<br>
# <br>
# **History**<br>
# coding 2025-12-11 : 1st coding<br>
# update 2026-05-18 : Improvement in orbit calculation speed<br>
# <br>
# (c) 2026 Kiyoaki Okudaira - Kyushu University Hanada Lab (SSDL) / University of Washington / IAU CPS SatHub

# %% [markdown]
# ### Parameters
# **Image PATH**

# %%
image_PATH = "" # FITS file PATH | str

# %% [markdown]
# **Observation**<br>
# All datetime should be in UTC

# %%
obs_metadata   = "AUTO" # "AUTO" or "MANUAL" : If "AUTO", observation date and exposure read from header | str
obs_begin      = "2025-12-11T10:00:00.000" # UTC Date and time observation begin [YYYY-MM-DDTHH:MM:SS.SSS] | str
obs_exposure   = 1   # Exposure [sec] | int or float
fov_radius_deg = 1.5 # Object search range [deg] | int or float

# %% [markdown]
# **TLE Download settings**<br>
# Downloading from space-track.org

# %%
tle_dt_range = 2 # TLE range from observation date | int > 0
norad_id = False

# %% [markdown]
# ### Import and initial settings

# %% [markdown]
# **PATH setting**

# %%
base_PATH = "/Users/kiyoaki/VScode/satphotometry_package/"
output_PATH = base_PATH + "output"
input_PATH = base_PATH + "input"
spice_myfile_PATH = "/Users/kiyoaki/VScode/satphotometry_package/config/myfile.txt"
tle_PATH = "/Users/kiyoaki/VScode/satphotometry_package/input/tle/13056.txt" # If download_tle is False | str

# %% [markdown]
# **SPICE toolkit**<br>
# import spiceypy and start up SPICE kernel

# %%
import spiceypy as spice
spice.furnsh(spice_myfile_PATH)

# %% [markdown]
# **Standard libraries**

# %%
from datetime import datetime, timedelta
import numpy as np
from os import path
import matplotlib as mpl
from matplotlib import pyplot as plt
from matplotlib.transforms import Affine2D
from itertools import cycle
from tqdm.notebook import tqdm
import json
import cal_satorbit

from astropy.time import Time
import astropy.units as u
from astropy.io import fits
from astropy.wcs import WCS
from astropy.coordinates import SkyCoord

# %% [markdown]
# **Satphotometry library**<br>
# satphotometry.satorbit must be imported after starting up SPICE kernel

# %%
from satphotometry import gettle,fitsparser

# %% [markdown]
# **Observatory setting**

# %%
# from input.obs_site.KUPT import *
from input.obs_site.DECAM import *
# obs_gd_lon_deg = 130.0 + (12.0 + 42.0 / 60.0) / 60.0    # [deg]
# obs_gd_lat_deg = 33.0 + (35.0 + 56.0 / 60.0) / 60.0     # [deg]
# obs_gd_height  = 0.073  # [km]

# wavelength_m = 0.5e-6   #[m]
# aperture_m   = 508.0e-3 #[m]

obs_params = [obs_gd_lon_deg,obs_gd_lat_deg,obs_gd_height,wavelength_m,aperture_m]

# %% [markdown]
# **Space-track.org settings**<br>
# Set your space-track.org identity and password at `./config/space-track-org.config`

# %%
with open(f'{base_PATH}config/space-track-org.config') as f:
    st_config = json.load(f)
    st_user_id  = st_config["identity"] # space-track.org user id | str
    st_password = st_config["password"] # space-track.org password | str

# %% [markdown]
# ### FITS Handling
# **Read FITS file**<br>
# This cell should be re-written for FITS products from each telescope / observatory

# %%
hdu = fits.open(image_PATH)

ccd_header = hdu[fits_ccd_hdu].header
ccd_data = hdu[fits_ccd_hdu].data

if fits_primary_hdu is not None:
    main_header = hdu[fits_primary_hdu].header
else:
    main_header = ccd_header

ccd_wcs = WCS(ccd_header)

# %% [markdown]
# **Observation date, time and exposure**

# %%
metadata = fitsparser.LEOfitsparser.parse_metadata(main_header,ccd_header,[],[],True,False)
# matadata = fitsparser.ASTR499.integrate_ALEX_metadata(metadata,row)

if obs_metadata == "AUTO":
    obs_exposure = metadata["EXPTIME"]
    obs_begin = metadata["DATE-OBS"]
    if len(obs_begin)<19:
        obs_begin = obs_begin + "T" + ccd_header["UT"]

if norad_id is False:
    obs_step = min(obs_exposure/4,15)
else:
    obs_step = min(obs_exposure/4,20)
obs_begin_dt = datetime.strptime(obs_begin[0:19], "%Y-%m-%dT%H:%M:%S") - timedelta(seconds=obs_exposure)
obs_end = datetime.strftime(obs_begin_dt+timedelta(seconds=obs_exposure*3+obs_step), "%Y-%m-%dT%H:%M:%S")

# %% [markdown]
# **SkyCoord**

# %%
coord = SkyCoord(ra=main_header["TELRA"], dec=main_header["TELDEC"], unit=(u.hour, u.deg))
fov_center_ra_deg = coord.icrs.ra.value
fov_center_dec_deg = coord.icrs.dec.value

# %% [markdown]
# ### Orbit calculation

# %% [markdown]
# **Download TLE file**<br>
# Download latest Two-Line Element set from space-track.org

# %%
if norad_id == False:
    tle_PATH = "{0}/tle/{1}.tle".format(input_PATH,obs_begin[0:10])
else:
    tle_PATH = "{0}/tle/{1}_{2}.tle".format(input_PATH,obs_begin[0:10],norad_id)
if path.exists(tle_PATH) is not True:
    if norad_id == False:
        status,tle_result = gettle.space_track.get_past_TLEs(obs_begin[0:10],tle_dt_range,st_user_id,st_password)
    else:
        status,tle_result = gettle.space_track.get_past_TLE(obs_begin[0:10],tle_dt_range,norad_id,st_user_id,st_password,False)
    if status == 200:
        with open(tle_PATH,mode="w") as f:
            f.write(tle_result)
    else:
        raise ValueError("Failed to download Two-Line Element set or NORAD catalog number is invalid.")

# %% [markdown]
# **Parse TLE file**

# %%
tle_dict = gettle.parse.parse_tles_file(tle_PATH)
filtered_tle_dict = gettle.parse.filter_nearest_tles(tle_dict, obs_begin[0:19])

# %% [markdown]
# **Function for FOV judgement**

# %%
def angular_separation_fast_deg(ra1_deg, dec1_deg, ra2_deg, dec2_deg):
    """
    Spherical angular separation [deg].
    ra1_deg, dec1_deg: scalar
    ra2_deg, dec2_deg: scalar or array
    """

    ra1 = np.deg2rad(ra1_deg)
    dec1 = np.deg2rad(dec1_deg)
    ra2 = np.deg2rad(ra2_deg)
    dec2 = np.deg2rad(dec2_deg)

    dra = ra2 - ra1

    a = (
        np.sin((dec2 - dec1) / 2.0) ** 2
        + np.cos(dec1) * np.cos(dec2) * np.sin(dra / 2.0) ** 2
    )

    a = np.clip(a, 0.0, 1.0)

    return np.rad2deg(2.0 * np.arcsin(np.sqrt(a)))


def interpolate_radec_for_search(ra_deg, dec_deg, n_interp=100):
    ra_deg = np.asarray(ra_deg, dtype=float)
    dec_deg = np.asarray(dec_deg, dtype=float)

    if len(ra_deg) < 2:
        return ra_deg % 360.0, dec_deg

    ra_unwrapped = np.rad2deg(np.unwrap(np.deg2rad(ra_deg)))

    t = np.arange(len(ra_unwrapped), dtype=float)

    t_fine = np.linspace(
        0,
        len(ra_unwrapped) - 1,
        (len(ra_unwrapped) - 1) * n_interp + 1,
    )

    ra_fine = np.interp(t_fine, t, ra_unwrapped) % 360.0
    dec_fine = np.interp(t_fine, t, dec_deg)

    return ra_fine, dec_fine


def in_circular_fov(
    ra_deg,
    dec_deg,
    fov_center_ra_deg,
    fov_center_dec_deg,
    fov_radius_deg,
):
    sep_deg = angular_separation_fast_deg(
        fov_center_ra_deg,
        fov_center_dec_deg,
        ra_deg,
        dec_deg,
    )

    return np.any(sep_deg <= fov_radius_deg)


def output_table_to_satchecker_positions(
    output,
    fov_center_ra_deg,
    fov_center_dec_deg,
    fov_radius_deg=None,
    tle_epoch_utc=None,
    only_inside_fov=True,
):
    positions = []

    for row in output:
        date_time_raw = row["YYYY-MM-DDThh:mm:ss"]

        t = Time(date_time_raw, format="isot", scale="utc")

        ra = float(row["ra[deg]"])
        dec = float(row["dec[deg]"])

        angle = float(
            angular_separation_fast_deg(
                fov_center_ra_deg,
                fov_center_dec_deg,
                ra,
                dec,
            )
        )

        if only_inside_fov and fov_radius_deg is not None:
            if angle > fov_radius_deg:
                continue

        position = {
            "altitude": round(float(row["el[deg]"]), 8),
            "angle": round(angle, 8),
            "azimuth": round(float(row["az[deg]"]), 8),
            "date_time": t.datetime.strftime("%Y-%m-%d %H:%M:%S UTC"),
            "dec": round(dec, 8),
            "julian_date": round(float(t.jd), 8),
            "ra": round(ra, 8),
            "tle_epoch": tle_epoch_utc,
            "range_km": round(float(row["range[km]"]), 6),
        }

        positions.append(position)

    return positions

# %% [markdown]
# **Canvas**

# %%
satchecker_fov_result = {
    "data": {
        "satellites": {},
        "total_position_results": 0,
        "total_satellites": 0,
    },
    "source": "SatPhotometry Package Identify Sat",
    "version": "1.0.0",
}

intldess = []

# %% [markdown]
# **SGP4 propagation**

# %%
# Search conditions
print("--------------------------------------------------------------------------------")
print(" Search range")
print("--------------------------------------------------------------------------------")
print(" FOV center RA    [deg] : {0}".format(round(fov_center_ra_deg, 6)))
print(" FOV center Dec   [deg] : {0}".format(round(fov_center_dec_deg, 6)))
print(" FOV radius       [deg] : {0}".format(round(fov_radius_deg, 6)))
print(" Search objects type   : ALL SATELLITES AND DEBRIS")
print(" Search date range     : {0} +- {1} DAYS".format(obs_begin[0:10], tle_dt_range))
print("--------------------------------------------------------------------------------")

# observatory parameters
ctx = cal_satorbit.init_satorbit_context(
    obs_begin=obs_begin,
    obs_end=obs_end,
    obs_step=obs_step,
    obs_params=obs_params,
    spice_myfile_PATH=spice_myfile_PATH,
)

# SGP4
try:
    for i in tqdm(range(len(filtered_tle_dict)), desc="Calculating SGP4 Propagation "):
        if i < 1:
            tqdm.write("--------------------------------------------------------------------------------")
            tqdm.write(" Artificial objects in search range")
            tqdm.write("--------------------------------------------------------------------------------")

        tle_input = [
            filtered_tle_dict[i]["name"],
            filtered_tle_dict[i]["line1"],
            filtered_tle_dict[i]["line2"],
        ]

        # SGP4 for all satellites
        try:
            (
                objname,
                norad_id,
                intldes,
                tle_epoch_utc,
                ra_deg,
                dec_deg,
                umbra,
            ) = cal_satorbit.cal_satorbit_radec_only(tle_input, ctx)

        except Exception:
            continue

        # Exclude umbra points
        visible_mask = ~umbra

        if np.sum(visible_mask) < 2:
            continue

        ra_visible = ra_deg[visible_mask]
        dec_visible = dec_deg[visible_mask]

        # Find possible satellites
        output_ra, output_dec = interpolate_radec_for_search(
            ra_visible,
            dec_visible,
            n_interp=1000,
        )

        possible_obj = in_circular_fov(
            output_ra,
            output_dec,
            fov_center_ra_deg=fov_center_ra_deg,
            fov_center_dec_deg=fov_center_dec_deg,
            fov_radius_deg=fov_radius_deg,
        )

        if not possible_obj:
            continue

        # SGP4 for possible satellites
        try:
            obs_step_full = min(obs_exposure / 4.0, 1.0)

            ctx_full = cal_satorbit.make_context_with_new_obs_step(
                ctx=ctx,
                obs_begin=obs_begin,
                obs_end=obs_end,
                obs_step=obs_step_full,
            )

            (
                objname,
                norad_id,
                intldes,
                tle_epoch_utc,
                output,
            ) = cal_satorbit.cal_satorbit_full(tle_input, ctx_full)

        except Exception:
            continue

        # Exclude umbra points
        output = output[output["umbra"] == False]

        # Sort to SatChecker result format
        positions = output_table_to_satchecker_positions(
            output=output,
            fov_center_ra_deg=fov_center_ra_deg,
            fov_center_dec_deg=fov_center_dec_deg,
            fov_radius_deg=fov_radius_deg,
            tle_epoch_utc=tle_epoch_utc,
            only_inside_fov=True,
        )

        if len(positions) == 0:
            continue

        # Write result 
        obs_time = Time(obs_begin, format="isot", scale="utc")
        tle_epoch_time = Time(
            tle_epoch_utc.replace(" UTC", ""),
            format="iso",
            scale="utc",
        )

        if tle_epoch_time < obs_time:
            tle_epoch_relation = "BEFORE"
        else:
            tle_epoch_relation = "AFTER"

        satellite_key = f"{objname} ({int(norad_id)}) {tle_epoch_relation}"

        satchecker_fov_result["data"]["satellites"][satellite_key] = {
            "name": objname,
            "norad_id": int(norad_id),
            "positions": positions,
            "international_designator": intldes,
            "tle_epoch_relation": tle_epoch_relation,
        }

        satchecker_fov_result["data"]["total_position_results"] += len(positions)

        if intldes not in intldess:
            tqdm.write(
                " * {0} (INTLDES {1} / NORAD CAT ID {2})".format(
                    objname,
                    intldes,
                    norad_id,
                )
            )

        intldess.append(intldes)

finally:
    # SPICE kernel clear
    cal_satorbit.clear_satorbit_context()

# Update result
satchecker_fov_result["data"]["total_satellites"] = len(
    satchecker_fov_result["data"]["satellites"]
)

# Search conditions
print("--------------------------------------------------------------------------------")

# %% [markdown]
# ### Output
# **Save as JSON**

# %%
with open(output_PATH + f"/identification/{path.splitext(path.basename(image_PATH))[0]}.json",'w') as json_output:
    json.dump(satchecker_fov_result, json_output, ensure_ascii=False, indent=4, sort_keys=True, separators=(',', ': '))

# %% [markdown]
# **Plot functions**

# %%
def get_satchecker_data(result):
    if isinstance(result, list):
        if len(result) == 0:
            raise ValueError("satchecker_fov_result is an empty list.")
        result = result[0]

    return result["data"]

def make_fov_circle_radec(
    fov_center_ra_deg,
    fov_center_dec_deg,
    fov_radius_deg,
    n_points=360,
):
    center = SkyCoord(
        ra=fov_center_ra_deg * u.deg,
        dec=fov_center_dec_deg * u.deg,
        frame="icrs",
    )

    pa = np.linspace(0, 360, n_points) * u.deg

    circle = center.directional_offset_by(
        position_angle=pa,
        separation=fov_radius_deg * u.deg,
    )

    return np.column_stack([circle.ra.deg, circle.dec.deg])

# %% [markdown]
# **Plot**

# %%
# Settings
fig = plt.figure(figsize=(16, 16))
ax = fig.add_subplot(111, projection=ccd_wcs)

im = ax.imshow(
    ccd_data,
    cmap="gray",
    origin="lower",
    vmin=np.percentile(ccd_data, 5),
    vmax=np.percentile(ccd_data, 95),
    zorder=2,
)

# RA/Dec axis labels and format in degree
ax.coords[0].set_axislabel("RA [deg]")
ax.coords[1].set_axislabel("Dec [deg]")

ax.coords[0].set_format_unit(u.deg)
ax.coords[1].set_format_unit(u.deg)

ax.coords[0].set_major_formatter("d.ddd")
ax.coords[1].set_major_formatter("d.ddd")

# Grid
ax.coords.grid(
    color='lightgray',
    linestyle="--",
    linewidth=1.0,
    alpha=0.7,
    zorder=0,
)

ax.coords[0].set_ticks(color='lightgray')
ax.coords[1].set_ticks(color='lightgray')

# Make circular FOV boundary
fov_circle_radec = make_fov_circle_radec(
    fov_center_ra_deg=fov_center_ra_deg,
    fov_center_dec_deg=fov_center_dec_deg,
    fov_radius_deg=fov_radius_deg,
    n_points=720,
)

# Compute display range from FOV circle
fov_circle_xy = ccd_wcs.wcs_world2pix(fov_circle_radec, 0)

fov_x = fov_circle_xy[:, 0]
fov_y = fov_circle_xy[:, 1]

valid = np.isfinite(fov_x) & np.isfinite(fov_y)
fov_x = fov_x[valid]
fov_y = fov_y[valid]

margin_frac = 0.05

x_width = np.nanmax(fov_x) - np.nanmin(fov_x)
y_width = np.nanmax(fov_y) - np.nanmin(fov_y)

x_margin = x_width * margin_frac
y_margin = y_width * margin_frac

x_min_fov = np.nanmin(fov_x) - x_margin
x_max_fov = np.nanmax(fov_x) + x_margin
y_min_fov = np.nanmin(fov_y) - y_margin
y_max_fov = np.nanmax(fov_y) + y_margin

# Plot circular FOV boundary
ax.plot(
    fov_circle_radec[:, 0],
    fov_circle_radec[:, 1],
    transform=ax.get_transform("world"),
    # color="gray",
    # lw=2,
    c='0.75',
    ls='--',
    label=f"Query FOV (r = {fov_radius_deg} deg)",
)

ax.scatter(
    fov_center_ra_deg,
    fov_center_dec_deg,
    transform=ax.get_transform("world"),
    s=160,
    marker="+",
    c='0.75',
    label="FOV center",
)

# Plot satellite tracks from SatChecker FOV dict
data = get_satchecker_data(satchecker_fov_result)
satellites = data["satellites"]

plotted_ids = set()

color_cycle = cycle(mpl.rcParams["axes.prop_cycle"].by_key()["color"]) # Dictionary for plot color
satellite_color_dict = {}

for satellite_key, satellite in satellites.items():

    name = satellite.get("name", satellite_key)
    norad_id = satellite.get("norad_id", "UNKNOWN")
    intldes = satellite.get("international_designator", None)

    positions = satellite.get("positions", [])

    if len(positions) == 0:
        continue

    orbit_radecs = np.array(
        [
            [p["ra"], p["dec"]]
            for p in positions
            if p.get("ra") is not None and p.get("dec") is not None
        ],
        dtype=float,
    )

    if len(orbit_radecs) == 0:
        continue

    if "angle" in positions[0]:
        inside_fov = np.array(
            [
                p.get("angle", np.inf) <= fov_radius_deg
                for p in positions
                if p.get("ra") is not None and p.get("dec") is not None
            ],
            dtype=bool,
        )

        orbit_radecs_inside = orbit_radecs[inside_fov]

        if len(orbit_radecs_inside) >= 2:
            plot_radecs = orbit_radecs_inside
        else:
            plot_radecs = orbit_radecs
    else:
        plot_radecs = orbit_radecs

    try:
        orbit_xy = ccd_wcs.wcs_world2pix(plot_radecs, 0)
    except Exception as e:
        print(f"Warning: WCS conversion failed for {satellite_key}: {e}")
        continue

    orbit_x = orbit_xy[:, 0]
    orbit_y = orbit_xy[:, 1]

    in_plot_range = (
        (orbit_x >= x_min_fov) & (orbit_x <= x_max_fov) &
        (orbit_y >= y_min_fov) & (orbit_y <= y_max_fov)
    )

    if not np.any(in_plot_range):
        continue

    if intldes is not None:
        label_base = f"{name} ({intldes} / {norad_id})"
        annotation = f" {name} ({norad_id})"
        unique_id = intldes
    else:
        label_base = f"{name} ({norad_id})"
        annotation = f" {name} ({norad_id})"
        unique_id = str(norad_id)

    # Change linestyle by TLE epoch
    # BEFORE observation: solid line
    # AFTER  observation: dashed line
    tle_epoch_relation = satellite.get("tle_epoch_relation", "UNKNOWN")

    if tle_epoch_relation == "BEFORE":
        linestyle = "-"
        markerstyle = "."
    elif tle_epoch_relation == "AFTER":
        linestyle = "--"
        markerstyle = "^"
    else:
        linestyle = "-."
        markerstyle = ","

    label = f"{label_base}"

    # Plot color
    if unique_id not in satellite_color_dict:
        satellite_color_dict[unique_id] = next(color_cycle)
    if unique_id not in plotted_ids:
        label = label_base
    else:
        label = "_nolegend_"

    color = satellite_color_dict[unique_id]

    ax.plot(
        plot_radecs[:, 0],
        plot_radecs[:, 1],
        transform=ax.get_transform("world"),
        label=label,
        lw=2,
        color=color,
        linestyle=linestyle,
    )

    ax.scatter(
        plot_radecs[:, 0],
        plot_radecs[:, 1],
        transform=ax.get_transform("world"),
        s=10,
        color=color,
        marker=markerstyle
    )

    if unique_id not in plotted_ids:
        first_visible_idx = np.where(in_plot_range)[0][0]

        ax.annotate(
            annotation,
            xy=(
                plot_radecs[first_visible_idx, 0],
                plot_radecs[first_visible_idx, 1],
            ),
            xycoords=ax.get_transform("world"),
            xytext=(5, 5),
            textcoords="offset points",
            fontsize=12,
            color=color,
        )

    plotted_ids.add(unique_id)

# Set FOV display range
ax.set_xlim(x_min_fov, x_max_fov)
ax.set_ylim(y_min_fov, y_max_fov)
ax.invert_xaxis()
ax.set_autoscale_on(False)

# Legend
ax.legend(loc='upper left', fontsize="10")

plt.show()

# %% [markdown]
# **Plot (for DECam)**

# %%
# CCD image pixel coordinates -> reference CCD pixel coordinates
def make_affine_to_reference_wcs(source_wcs, reference_wcs, data_shape):
    ny, nx = data_shape

    # Affine Transformation
    src_x = np.array([0, nx - 1, 0], dtype=float)
    src_y = np.array([0, 0, ny - 1], dtype=float)

    # source CCD pixel -> world
    ra, dec = source_wcs.wcs_pix2world(src_x, src_y, 0)

    # world -> reference CCD pixel
    ref_x, ref_y = reference_wcs.wcs_world2pix(ra, dec, 0)

    # x_ref = a*x + b*y + c
    # y_ref = d*x + e*y + f
    A = np.vstack([src_x, src_y, np.ones_like(src_x)]).T

    a, b, c = np.linalg.solve(A, ref_x)
    d, e, f = np.linalg.solve(A, ref_y)

    affine = Affine2D.from_values(
        a, d,
        b, e,
        c, f,
    )

    corner_x = np.array([-0.5, nx - 0.5, nx - 0.5, -0.5])
    corner_y = np.array([-0.5, -0.5, ny - 0.5, ny - 0.5])

    corner_ra, corner_dec = source_wcs.wcs_pix2world(corner_x, corner_y, 0)
    footprint_x, footprint_y = reference_wcs.wcs_world2pix(
        corner_ra,
        corner_dec,
        0,
    )

    return affine, footprint_x, footprint_y

# Open DECam image
hdu = fits.open("/Users/kiyoaki/Downloads/c4d_190101_012442_ooi_g_ls9.fits.fz")

# hdu[0] : primary header
# hdu[1] - hdu[62] : CCD images
ccd_hdu_indices = range(1, 62)

# Based on hdu[28]
reference_ccd_index = 28
ccd_wcs = WCS(hdu[reference_ccd_index].header)

# Global display scale
sample_values = []

for i in ccd_hdu_indices:
    if hdu[i].data is None:
        continue

    data_i = np.asarray(hdu[i].data, dtype=float)
    finite_values = data_i[np.isfinite(data_i)]

    if finite_values.size == 0:
        continue

    sample_values.append(finite_values[::20])

sample_values = np.concatenate(sample_values)

vmin = np.nanpercentile(sample_values, 5)
vmax = np.nanpercentile(sample_values, 95)

# Figure with reference CCD WCS
fig = plt.figure(figsize=(25, 25))
ax = fig.add_subplot(111, projection=ccd_wcs)

# Plot all CCDs on CCD 28 WCS
all_footprint_x = []
all_footprint_y = []

for i in ccd_hdu_indices:

    if hdu[i].data is None:
        continue

    data_i = np.asarray(hdu[i].data, dtype=float)
    wcs_i = WCS(hdu[i].header)

    try:
        affine_i, footprint_x, footprint_y = make_affine_to_reference_wcs(
            source_wcs=wcs_i,
            reference_wcs=ccd_wcs,
            data_shape=data_i.shape,
        )
    except Exception as e:
        print(f"Warning: CCD hdu[{i}] WCS transform failed: {e}")
        continue

    ny, nx = data_i.shape

    ax.imshow(
        data_i,
        cmap="gray",
        origin="lower",
        vmin=vmin,
        vmax=vmax,
        extent=(-0.5, nx - 0.5, -0.5, ny - 0.5),
        transform=affine_i + ax.transData,
        interpolation="nearest",
        zorder=2,
    )

    all_footprint_x.append(footprint_x)
    all_footprint_y.append(footprint_y)

    ax.plot(
        np.append(footprint_x, footprint_x[0]),
        np.append(footprint_y, footprint_y[0]),
        transform=ax.transData,
        color="0.6",
        lw=0.5,
        alpha=0.7,
    )


all_footprint_x = np.concatenate(all_footprint_x)
all_footprint_y = np.concatenate(all_footprint_y)

# RA/Dec axis labels and format in degree
ax.coords[0].set_axislabel("RA [deg]")
ax.coords[1].set_axislabel("Dec [deg]")

ax.coords[0].set_format_unit(u.deg)
ax.coords[1].set_format_unit(u.deg)

ax.coords[0].set_major_formatter("d.ddd")
ax.coords[1].set_major_formatter("d.ddd")

# Grid
ax.coords.grid(
    color="lightgray",
    linestyle="--",
    linewidth=1.0,
    alpha=0.7,
    zorder=0,
)

ax.coords[0].set_ticks(color="lightgray")
ax.coords[1].set_ticks(color="lightgray")

# Make circular FOV boundary
fov_circle_radec = make_fov_circle_radec(
    fov_center_ra_deg=fov_center_ra_deg,
    fov_center_dec_deg=fov_center_dec_deg,
    fov_radius_deg=fov_radius_deg,
    n_points=720,
)

# FOV circle in reference CCD pixel coordinates
fov_circle_xy = ccd_wcs.wcs_world2pix(fov_circle_radec, 0)

fov_x = fov_circle_xy[:, 0]
fov_y = fov_circle_xy[:, 1]

valid = np.isfinite(fov_x) & np.isfinite(fov_y)
fov_x = fov_x[valid]
fov_y = fov_y[valid]

# Plot circular FOV boundary
ax.plot(
    fov_circle_radec[:, 0],
    fov_circle_radec[:, 1],
    transform=ax.get_transform("world"),
    c="0.75",
    ls="--",
    lw=2,
    label=f"Query FOV (r = {fov_radius_deg} deg)",
)

ax.scatter(
    fov_center_ra_deg,
    fov_center_dec_deg,
    transform=ax.get_transform("world"),
    s=160,
    marker="+",
    c="0.75",
    label="FOV center",
)

# Plot satellite tracks from SatChecker FOV dict
data = get_satchecker_data(satchecker_fov_result)
satellites = data["satellites"]

plotted_ids = set()

color_cycle = cycle(mpl.rcParams["axes.prop_cycle"].by_key()["color"])
satellite_color_dict = {}

for satellite_key, satellite in satellites.items():

    name = satellite.get("name", satellite_key)
    norad_id = satellite.get("norad_id", "UNKNOWN")
    intldes = satellite.get("international_designator", None)

    positions = satellite.get("positions", [])

    if len(positions) == 0:
        continue

    orbit_radecs = np.array(
        [
            [p["ra"], p["dec"]]
            for p in positions
            if p.get("ra") is not None and p.get("dec") is not None
        ],
        dtype=float,
    )

    if len(orbit_radecs) == 0:
        continue

    if "angle" in positions[0]:
        inside_fov = np.array(
            [
                p.get("angle", np.inf) <= fov_radius_deg
                for p in positions
                if p.get("ra") is not None and p.get("dec") is not None
            ],
            dtype=bool,
        )

        orbit_radecs_inside = orbit_radecs[inside_fov]

        if len(orbit_radecs_inside) >= 2:
            plot_radecs = orbit_radecs_inside
        else:
            plot_radecs = orbit_radecs
    else:
        plot_radecs = orbit_radecs

    try:
        orbit_xy = ccd_wcs.wcs_world2pix(plot_radecs, 0)
    except Exception as e:
        print(f"Warning: WCS conversion failed for {satellite_key}: {e}")
        continue

    orbit_x = orbit_xy[:, 0]
    orbit_y = orbit_xy[:, 1]

    x_min_all = np.nanmin(all_footprint_x)
    x_max_all = np.nanmax(all_footprint_x)
    y_min_all = np.nanmin(all_footprint_y)
    y_max_all = np.nanmax(all_footprint_y)

    in_plot_range = (
        (orbit_x >= x_min_all) & (orbit_x <= x_max_all) &
        (orbit_y >= y_min_all) & (orbit_y <= y_max_all)
    )

    if not np.any(in_plot_range):
        continue

    if intldes is not None:
        label_base = f"{name} ({intldes} / {norad_id})"
        annotation = f" {name} ({norad_id})"
        unique_id = intldes
    else:
        label_base = f"{name} ({norad_id})"
        annotation = f" {name} ({norad_id})"
        unique_id = str(norad_id)

    tle_epoch_relation = satellite.get("tle_epoch_relation", "UNKNOWN")

    if tle_epoch_relation == "BEFORE":
        linestyle = "-"
        markerstyle = "."
    elif tle_epoch_relation == "AFTER":
        linestyle = "--"
        markerstyle = "^"
    else:
        linestyle = "-."
        markerstyle = ","

    if unique_id not in satellite_color_dict:
        satellite_color_dict[unique_id] = next(color_cycle)

    if unique_id not in plotted_ids:
        label = label_base
    else:
        label = "_nolegend_"

    color = satellite_color_dict[unique_id]

    ax.plot(
        plot_radecs[:, 0],
        plot_radecs[:, 1],
        transform=ax.get_transform("world"),
        label=label,
        lw=2,
        color=color,
        linestyle=linestyle,
        alpha=0.7,
    )

    ax.scatter(
        plot_radecs[:, 0],
        plot_radecs[:, 1],
        transform=ax.get_transform("world"),
        s=10,
        color=color,
        marker=markerstyle,
    )

    if unique_id not in plotted_ids:
        first_visible_idx = np.where(in_plot_range)[0][0]

        ax.annotate(
            annotation,
            xy=(
                plot_radecs[0, 0],
                plot_radecs[0, 1],
            ),
            xycoords=ax.get_transform("world"),
            xytext=(5, 5),
            textcoords="offset points",
            fontsize=16,
            color=color,
        )

    plotted_ids.add(unique_id)

# Set display range: all CCDs + FOV
plot_x = np.concatenate([all_footprint_x, fov_x])
plot_y = np.concatenate([all_footprint_y, fov_y])

valid = np.isfinite(plot_x) & np.isfinite(plot_y)
plot_x = plot_x[valid]
plot_y = plot_y[valid]

margin_frac = 0.05

x_width = np.nanmax(plot_x) - np.nanmin(plot_x)
y_width = np.nanmax(plot_y) - np.nanmin(plot_y)

x_margin = x_width * margin_frac
y_margin = y_width * margin_frac

x_min_plot = np.nanmin(plot_x) - x_margin
x_max_plot = np.nanmax(plot_x) + x_margin
y_min_plot = np.nanmin(plot_y) - y_margin
y_max_plot = np.nanmax(plot_y) + y_margin

ax.set_xlim(x_min_plot, x_max_plot)
ax.set_ylim(y_min_plot, y_max_plot)

ax.invert_xaxis()
ax.set_autoscale_on(False)

# Legend
ax.legend(loc="upper left", fontsize=16)

plt.show()
